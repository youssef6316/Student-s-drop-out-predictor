# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#   Marital status                  Application mode Application order  \
# 0         single    2nd phase - general contingent        6th choice
# 1         single  International student (bachelor)        2nd choice
# 2         single   1st phase - general contingent         6th choice
# 3         single    2nd phase - general contingent        3rd choice
# 4        married                 Over 23 years old        2nd choice
#
#                                 Course Daytime/evening attendance  \
# 0      Animation and Multimedia Design                    daytime
# 1                             Tourism                     daytime
# 2                 Communication Design                    daytime
# 3         Journalism and Communication                    daytime
# 4  Social Service (evening attendance)                    evening
#
#   Previous qualification  Previous qualification (grade) Nacionality  \
# 0    Secondary education                           122.0  Portuguese
# 1    Secondary education                           160.0  Portuguese
# 2    Secondary education                           122.0  Portuguese
# 3    Secondary education                           122.0  Portuguese
# 4    Secondary education                           100.0  Portuguese
#
#   Mother's qualification Father's qualification  ...  \
# 0     Basic Ed 3rd Cycle             Other 11th  ...
# 1    Secondary Education                 Degree  ...
# 2     Basic Ed 1st Cycle     Basic Ed 1st Cycle  ...
# 3     Basic Ed 2nd Cycle     Basic Ed 1st Cycle  ...
# 4     Basic Ed 1st Cycle     Basic Ed 2nd Cycle  ...
#
#   Curricular units 2nd sem (credited) Curricular units 2nd sem (enrolled)  \
# 0                                   0                                   0
# 1                                   0                                   6
# 2                                   0                                   6
# 3                                   0                                   6
# 4                                   0                                   6
#
#    Curricular units 2nd sem (evaluations) Curricular units 2nd sem (approved)  \
# 0                                       0                                   0
# 1                                       6                                   6
# 2                                       0                                   0
# 3                                      10                                   5
# 4                                       6                                   6
#
#   Curricular units 2nd sem (grade)  \
# 0                         0.000000
# 1                        13.666667
# 2                         0.000000
# 3                        12.400000
# 4                        13.000000
#
#   Curricular units 2nd sem (without evaluations) Unemployment rate  \
# 0                                              0              10.8
# 1                                              0              13.9
# 2                                              0              10.8
# 3                                              0               9.4
# 4                                              0              13.9
#
#   Inflation rate   GDP    Target
# 0            1.4  1.74   Dropout
# 1           -0.3  0.79  Graduate
# 2            1.4  1.74   Dropout
# 3           -0.8 -3.12  Graduate
# 4           -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (4424, 37)

# %% [markdown]
# # Removing duplicate instances (if exist)

# %%
df.drop_duplicates()
# Out:
#      Marital status                  Application mode Application order  \
# 0            single    2nd phase - general contingent        6th choice
# 1            single  International student (bachelor)        2nd choice
# 2            single   1st phase - general contingent         6th choice
# 3            single    2nd phase - general contingent        3rd choice
# 4           married                 Over 23 years old        2nd choice
# ...             ...                               ...               ...
# 4419         single   1st phase - general contingent         7th choice
# 4420         single   1st phase - general contingent         3rd choice
# 4421         single   1st phase - general contingent         2nd choice
# 4422         single   1st phase - general contingent         2nd choice
# 4423         single            Ordinance No. 854-B/99        2nd choice
#
#                                    Course Daytime/evening attendance  \
# 0         Animation and Multimedia Design                    daytime
# 1                                Tourism                     daytime
# 2                    Communication Design                    daytime
# 3            Journalism and Communication                    daytime
# 4     Social Service (evening attendance)                    evening
# ...                                   ...                        ...
# 4419         Journalism and Communication                    daytime
# 4420         Journalism and Communication                    daytime
# 4421                              Nursing                    daytime
# 4422                           Management                    daytime
# 4423         Journalism and Communication                    daytime
#
#      Previous qualification  Previous qualification (grade)   Nacionality  \
# 0       Secondary education                           122.0    Portuguese
# 1       Secondary education                           160.0    Portuguese
# 2       Secondary education                           122.0    Portuguese
# 3       Secondary education                           122.0    Portuguese
# 4       Secondary education                           100.0    Portuguese
# ...                     ...                             ...           ...
# 4419    Secondary education                           125.0    Portuguese
# 4420    Secondary education                           120.0       Russian
# 4421    Secondary education                           154.0    Portuguese
# 4422    Secondary education                           180.0    Portuguese
# 4423    Secondary education                           152.0  Cape Verdean
#
#      Mother's qualification Father's qualification  ...  \
# 0        Basic Ed 3rd Cycle             Other 11th  ...
# 1       Secondary Education                 Degree  ...
# 2        Basic Ed 1st Cycle     Basic Ed 1st Cycle  ...
# 3        Basic Ed 2nd Cycle     Basic Ed 1st Cycle  ...
# 4        Basic Ed 1st Cycle     Basic Ed 2nd Cycle  ...
# ...                     ...                    ...  ...
# 4419    Secondary Education    Secondary Education  ...
# 4420    Secondary Education    Secondary Education  ...
# 4421     Basic Ed 1st Cycle     Basic Ed 1st Cycle  ...
# 4422     Basic Ed 1st Cycle     Basic Ed 1st Cycle  ...
# 4423     Basic Ed 2nd Cycle     Basic Ed 1st Cycle  ...
#
#      Curricular units 2nd sem (credited) Curricular units 2nd sem (enrolled)  \
# 0                                      0                                   0
# 1                                      0                                   6
# 2                                      0                                   6
# 3                                      0                                   6
# 4                                      0                                   6
# ...                                  ...                                 ...
# 4419                                   0                                   6
# 4420                                   0                                   6
# 4421                                   0                                   8
# 4422                                   0                                   5
# 4423                                   0                                   6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#      Curricular units 2nd sem (approved) Curricular units 2nd sem (grade)  \
# 0                                      0                         0.000000
# 1                                      6                        13.666667
# 2                                      0                         0.000000
# 3                                      5                        12.400000
# 4                                      6                        13.000000
# ...                                  ...                              ...
# 4419                                   5                        12.666667
# 4420                                   2                        11.000000
# 4421                                   1                        13.500000
# 4422                                   5                        12.000000
# 4423                                   6                        13.000000
#
#      Curricular units 2nd sem (without evaluations) Unemployment rate  \
# 0                                                 0              10.8
# 1                                                 0              13.9
# 2                                                 0              10.8
# 3                                                 0               9.4
# 4                                                 0              13.9
# ...                                             ...               ...
# 4419                                              0              15.5
# 4420                                              0              11.1
# 4421                                              0              13.9
# 4422                                              0               9.4
# 4423                                              0              12.7
#
#      Inflation rate   GDP    Target
# 0               1.4  1.74   Dropout
# 1              -0.3  0.79  Graduate
# 2               1.4  1.74   Dropout
# 3              -0.8 -3.12  Graduate
# 4              -0.3  0.79  Graduate
# ...             ...   ...       ...
# 4419            2.8 -4.06  Graduate
# 4420            0.6  2.02   Dropout
# 4421           -0.3  0.79   Dropout
# 4422           -0.8 -3.12  Graduate
# 4423            3.7 -1.70  Graduate
#
# [4424 rows x 37 columns]

# %% [markdown]
# # dealing with null values

# %%
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
sns.countplot(x='Target', data=df)
plt.xlabel('drop out results')
plt.ylabel('count')
plt.show()

# %% [markdown]
# enrolled class will be dropped as we are concerned only about dop outs & graduates only

# %%
df.shape
# Out:
# (4424, 37)

# %%
df = df[df['Target'] != 'Enrolled']

# %%
df.shape
# Out:
# (3630, 37)

# %%
df['Target'].unique()
# Out:
# array(['Dropout', 'Graduate'], dtype=object)

# %%
sns.countplot(x='Target', data=df)
plt.xlabel('drop out results')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # splitting features into categorical & numerical

# %%
features_data = df.iloc[:, :-1]
target_data = df.iloc[:, -1]

# %%
features_data.head()
# Out:
#   Marital status                  Application mode Application order  \
# 0         single    2nd phase - general contingent        6th choice
# 1         single  International student (bachelor)        2nd choice
# 2         single   1st phase - general contingent         6th choice
# 3         single    2nd phase - general contingent        3rd choice
# 4        married                 Over 23 years old        2nd choice
#
#                                 Course Daytime/evening attendance  \
# 0      Animation and Multimedia Design                    daytime
# 1                             Tourism                     daytime
# 2                 Communication Design                    daytime
# 3         Journalism and Communication                    daytime
# 4  Social Service (evening attendance)                    evening
#
#   Previous qualification  Previous qualification (grade) Nacionality  \
# 0    Secondary education                           122.0  Portuguese
# 1    Secondary education                           160.0  Portuguese
# 2    Secondary education                           122.0  Portuguese
# 3    Secondary education                           122.0  Portuguese
# 4    Secondary education                           100.0  Portuguese
#
#   Mother's qualification Father's qualification  ...  \
# 0     Basic Ed 3rd Cycle             Other 11th  ...
# 1    Secondary Education                 Degree  ...
# 2     Basic Ed 1st Cycle     Basic Ed 1st Cycle  ...
# 3     Basic Ed 2nd Cycle     Basic Ed 1st Cycle  ...
# 4     Basic Ed 1st Cycle     Basic Ed 2nd Cycle  ...
#
#   Curricular units 1st sem (without evaluations)  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#   Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                   0                                    0
# 1                                   0                                    6
# 2                                   0                                    6
# 3                                   0                                    6
# 4                                   0                                    6
#
#   Curricular units 2nd sem (evaluations) Curricular units 2nd sem (approved)  \
# 0                                      0                                   0
# 1                                      6                                   6
# 2                                      0                                   0
# 3                                     10                                   5
# 4                                      6                                   6
#
#   Curricular units 2nd sem (grade)  \
# 0                         0.000000
# 1                        13.666667
# 2                         0.000000
# 3                        12.400000
# 4                        13.000000
#
#   Curricular units 2nd sem (without evaluations) Unemployment rate  \
# 0                                              0              10.8
# 1                                              0              13.9
# 2                                              0              10.8
# 3                                              0               9.4
# 4                                              0              13.9
#
#   Inflation rate   GDP
# 0            1.4  1.74
# 1           -0.3  0.79
# 2            1.4  1.74
# 3           -0.8 -3.12
# 4           -0.3  0.79
#
# [5 rows x 36 columns]

# %%
target_data.head()
# Out:
# 0     Dropout
# 1    Graduate
# 2     Dropout
# 3    Graduate
# 4    Graduate
# Name: Target, dtype: object

# %%
features_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3630 entries, 0 to 4423
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  3630 non-null   object
#  1   Application mode                                3630 non-null   object
#  2   Application order                               3630 non-null   object
#  3   Course                                          3630 non-null   object
#  4   Daytime/evening attendance                      3630 non-null   object
#  5   Previous qualification                          3630 non-null   object
#  6   Previous qualification (grade)                  3630 non-null   float64
#  7   Nacionality                                     3630 non-null   object
#  8   Mother's qualification                          3630 non-null   object
#  9   Father's qualification                          3630 non-null   object
#  10  Mother's occupation                             3630 non-null   object
#  11  Father's occupation                             3630 non-null   object
#  12  Admission grade                                 3630 non-null   float64
#  13  Displaced                                       3630 non-null   object
#  14  Educational special needs                       3630 non-null   object
#  15  Debtor                                          3630 non-null   object
#  16  Tuition fees up to date                         3630 non-null   object
#  17  Gender                                          3630 non-null   object
#  18  Scholarship holder                              3630 non-null   object
#  19  Age at enrollment                               3630 non-null   int64
#  20  International                                   3630 non-null   object
#  21  Curricular units 1st sem (credited)             3630 non-null   int64
#  22  Curricular units 1st sem (enrolled)             3630 non-null   int64
#  23  Curricular units 1st sem (evaluations)          3630 non-null   int64
#  24  Curricular units 1st sem (approved)             3630 non-null   int64
#  25  Curricular units 1st sem (grade)                3630 non-null   float64
#  26  Curricular units 1st sem (without evaluations)  3630 non-null   int64
#  27  Curricular units 2nd sem (credited)             3630 non-null   int64
#  28  Curricular units 2nd sem (enrolled)             3630 non-null   int64
#  29  Curricular units 2nd sem (evaluations)          3630 non-null   int64
#  30  Curricular units 2nd sem (approved)             3630 non-null   int64
#  31  Curricular units 2nd sem (grade)                3630 non-null   float64
#  32  Curricular units 2nd sem (without evaluations)  3630 non-null   int64
#  33  Unemployment rate                               3630 non-null   float64
#  34  Inflation rate                                  3630 non-null   float64
#  35  GDP                                             3630 non-null   float64
# dtypes: float64(7), int64(11), object(18)
# memory usage: 1.0+ MB

# %%
categorical_data = features_data.select_dtypes(include='object')
categorical_data.head()
# Out:
#   Marital status                  Application mode Application order  \
# 0         single    2nd phase - general contingent        6th choice
# 1         single  International student (bachelor)        2nd choice
# 2         single   1st phase - general contingent         6th choice
# 3         single    2nd phase - general contingent        3rd choice
# 4        married                 Over 23 years old        2nd choice
#
#                                 Course Daytime/evening attendance  \
# 0      Animation and Multimedia Design                    daytime
# 1                             Tourism                     daytime
# 2                 Communication Design                    daytime
# 3         Journalism and Communication                    daytime
# 4  Social Service (evening attendance)                    evening
#
#   Previous qualification Nacionality Mother's qualification  \
# 0    Secondary education  Portuguese     Basic Ed 3rd Cycle
# 1    Secondary education  Portuguese    Secondary Education
# 2    Secondary education  Portuguese     Basic Ed 1st Cycle
# 3    Secondary education  Portuguese     Basic Ed 2nd Cycle
# 4    Secondary education  Portuguese     Basic Ed 1st Cycle
#
#   Father's qualification      Mother's occupation Father's occupation  \
# 0             Other 11th  Services/Security/Sales   Unskilled Workers
# 1                 Degree              Technicians         Technicians
# 2     Basic Ed 1st Cycle        Unskilled Workers   Unskilled Workers
# 3     Basic Ed 1st Cycle  Services/Security/Sales         Technicians
# 4     Basic Ed 2nd Cycle        Unskilled Workers   Unskilled Workers
#
#   Displaced Educational special needs Debtor Tuition fees up to date  Gender  \
# 0       yes                        no     no                     yes    male
# 1       yes                        no     no                      no    male
# 2       yes                        no     no                      no    male
# 3       yes                        no     no                     yes  female
# 4        no                        no     no                     yes  female
#
#   Scholarship holder International
# 0                 no            no
# 1                 no            no
# 2                 no            no
# 3                 no            no
# 4                 no            no

# %%
numerical_data = features_data.select_dtypes(include='number')
numerical_data.head()
# Out:
#    Previous qualification (grade)  Admission grade  Age at enrollment  \
# 0                           122.0            127.3                 20
# 1                           160.0            142.5                 19
# 2                           122.0            124.8                 19
# 3                           122.0            119.6                 20
# 4                           100.0            141.5                 45
#
#    Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 1st sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       8
# 4                                       9
#
#    Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         14.000000
# 2                                    0                          0.000000
# 3                                    6                         13.428571
# 4                                    5                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP
# 0             1.4  1.74
# 1            -0.3  0.79
# 2             1.4  1.74
# 3            -0.8 -3.12
# 4            -0.3  0.79

# %% [markdown]
# #  plotting categorical data

# %%
def plot_categorical_data(category: str, hue = False, width = 10, height = 12):  
    plt.figure(figsize = (width, height))
    sns.countplot(y = categorical_data[category], data = categorical_data, hue = df['Target'] if hue else None)
    plt.ylabel(f"{category}s")
    plt.xlabel("count")
    plt.legend()
    plt.grid(True)

# %%
plot_categorical_data('Course', hue = True, width = 15, height = 10)

# %% [markdown]
# max grads are from nursing and min drop outs are from management

# %%
plot_categorical_data('Marital status', hue = True, width = 25, height = 5)

# %%
plot_categorical_data('Daytime/evening attendance', hue = True, width = 15, height = 5)

# %% [markdown]
# student of evening time attendances have high probability to drop out over day time attendance students

# %%
plot_categorical_data('Gender', hue = True, width = 10, height = 5)

# %% [markdown]
# females are more probable to complete their education over boys who are more likely to drop out

# %%
plot_categorical_data('Displaced', hue = True, width = 10, height = 5)

# %%
plot_categorical_data('Previous qualification', hue = True, width = 30, height = 10)

# %% [markdown]
# # dropping columns of irrelevant features

# %%
print(f"ordinal df shape: {categorical_data.shape}")
print(f"Numerical df shape: {numerical_data.shape}")
# Out:
# ordinal df shape: (3630, 18)
# Numerical df shape: (3630, 18)

# %%
numerical_to_drop = [
    
]
categorical_to_drop = [
    'International',
    'Application mode',
]

numerical_data.drop(numerical_to_drop, axis = 1, inplace = True)
categorical_data.drop(categorical_to_drop, axis = 1, inplace = True)

# %%
print(f"ordinal df shape: {categorical_data.shape}")
print(f"Numerical df shape: {numerical_data.shape}")
# Out:
# ordinal df shape: (3630, 16)
# Numerical df shape: (3630, 18)

# %% [markdown]
# # encoding categorical features

# %%
ordinal_cols= ['Application order']
nominal_cols = [str(col) for col in categorical_data.columns if col not in ordinal_cols]

print(f"ordinal categories: {ordinal_cols}")
print(f"nominal categories: {nominal_cols}")
# Out:
# ordinal categories: ['Application order']
# nominal categories: ['Marital status', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder']

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

ordinal_encoder = OrdinalEncoder()

ordinal_encoded = ordinal_encoder.fit_transform(categorical_data[ordinal_cols])

ordinal_df = pd.DataFrame(ordinal_encoded, columns=ordinal_cols, index=categorical_data.index)

# %%
onehot_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

nominal_encoded = onehot_encoder.fit_transform(categorical_data[nominal_cols])

nominal_df = pd.DataFrame(nominal_encoded, columns = onehot_encoder.get_feature_names_out(nominal_cols), index = categorical_data.index)

# %%
print(f"ordinal df shape: {ordinal_df.shape}")
print(f"nominal df shape: {nominal_df.shape}")
# Out:
# ordinal df shape: (3630, 1)
# nominal df shape: (3630, 207)

# %% [markdown]
# # Feature Engineering for student's academic scores
#
# features of "Curricular Units 1st Semester" will be used to extract new features and dropping some to increase quality of data
# 1. increase ratio in grade = (sem_1 grade + sem_2 grade) / admission grade
# 2. gpa = ((evaluated credits sem 1 * sem 1 grade)+(evaluated credits of sem 2 * sem 2 grade)) / sum of evaluated credits of both semesters
# 3. approved rate = approved /Evaluated
# 4. completeness rate = Evaluated / enrolled

# %%
# Create a list to track added feature names
added_features = []

# Feature 1: Grade Increase Ratio
numerical_data['grade_increase_ratio'] = (
    numerical_data['Curricular units 1st sem (grade)'] + numerical_data['Curricular units 2nd sem (grade)']
) / (numerical_data['Admission grade'] + 1e-5)
added_features.append('grade_increase_ratio')

# Feature 2: Grade per Credit (semester 1 & 2)
numerical_data['grade_per_credit_sem_1'] = (
    numerical_data['Curricular units 1st sem (grade)'] / (numerical_data['Curricular units 1st sem (approved)'] + 1e-5)
)
added_features.append('grade_per_credit_sem_1')

numerical_data['grade_per_credit_sem_2'] = (
    numerical_data['Curricular units 2nd sem (grade)'] / (numerical_data['Curricular units 2nd sem (approved)'] + 1e-5)
)
added_features.append('grade_per_credit_sem_2')

# Feature 3: Grade Difference & Improvement Indicator
numerical_data['grade_diff'] = (
    numerical_data['Curricular units 2nd sem (grade)'] - numerical_data['Curricular units 1st sem (grade)']
)
added_features.append('grade_diff')

numerical_data['improved'] = (numerical_data['grade_diff'] > 0).astype(int)
added_features.append('improved')

# Feature 4: Cumulative Approval Rate
numerical_data['cumulative_approval_rate'] = (
    numerical_data['Curricular units 1st sem (approved)'] + numerical_data['Curricular units 2nd sem (approved)']
) / (
    numerical_data['Curricular units 1st sem (evaluations)'] + numerical_data['Curricular units 2nd sem (evaluations)'] + 1e-5
)
added_features.append('cumulative_approval_rate')

# Feature 6: Grade Quality Index (weighted grade by approved credits)
numerical_data['grade_points_avg'] = (
    numerical_data['Curricular units 1st sem (grade)'] * numerical_data['Curricular units 1st sem (evaluations)'] +
    numerical_data['Curricular units 2nd sem (grade)'] * numerical_data['Curricular units 2nd sem (evaluations)']
) / (
    numerical_data['Curricular units 1st sem (evaluations)'] + numerical_data['Curricular units 2nd sem (evaluations)'] + 1e-5
)
added_features.append('grade_points_avg')

# Feature 7: Age Penalty (inverse of age at enrollment)
numerical_data['age_penalty'] = 1 / (numerical_data['Age at enrollment'] + 1)
added_features.append('age_penalty')

# Feature 8: Approval rate w.r.t evaluated credits
numerical_data['approved_rate_sem_1'] = numerical_data['Curricular units 1st sem (approved)'] / (numerical_data['Curricular units 1st sem (evaluations)'] + 1e-5)
added_features.append('approved_rate_sem_1')

numerical_data['approved_rate_sem_2'] = numerical_data['Curricular units 2nd sem (approved)'] / (numerical_data['Curricular units 2nd sem (evaluations)'] + 1e-5)
added_features.append('approved_rate_sem_2')

# %%
print(f"added new features: {added_features}")
# Out:
# added new features: ['grade_increase_ratio', 'grade_per_credit_sem_1', 'grade_per_credit_sem_2', 'grade_diff', 'improved', 'cumulative_approval_rate', 'grade_points_avg', 'age_penalty', 'approved_rate_sem_1', 'approved_rate_sem_2']

# %%
numerical_data.head()
# Out:
#    Previous qualification (grade)  Admission grade  Age at enrollment  \
# 0                           122.0            127.3                 20
# 1                           160.0            142.5                 19
# 2                           122.0            124.8                 19
# 3                           122.0            119.6                 20
# 4                           100.0            141.5                 45
#
#    Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 1st sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       8
# 4                                       9
#
#    Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         14.000000
# 2                                    0                          0.000000
# 3                                    6                         13.428571
# 4                                    5                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  ...  grade_increase_ratio  \
# 0                                    0  ...              0.000000
# 1                                    0  ...              0.194152
# 2                                    0  ...              0.000000
# 3                                    0  ...              0.215958
# 4                                    0  ...              0.179034
#
#    grade_per_credit_sem_1  grade_per_credit_sem_2  grade_diff  improved  \
# 0                0.000000                0.000000    0.000000         0
# 1                2.333329                2.277774   -0.333333         0
# 2                0.000000                0.000000    0.000000         0
# 3                2.238092                2.479995   -1.028571         0
# 4                2.466662                2.166663    0.666667         1
#
#    cumulative_approval_rate  grade_points_avg  age_penalty  \
# 0                  0.000000          0.000000     0.047619
# 1                  0.999999         13.833322     0.050000
# 2                  0.000000          0.000000     0.050000
# 3                  0.611111         12.857136     0.047619
# 4                  0.733333         12.599992     0.021739
#
#    approved_rate_sem_1  approved_rate_sem_2
# 0             0.000000             0.000000
# 1             0.999998             0.999998
# 2             0.000000             0.000000
# 3             0.749999             0.500000
# 4             0.555555             0.999998
#
# [5 rows x 28 columns]

# %% [markdown]
# # cleaning numerical features from outliers

# %%
melted = numerical_data.melt(var_name='Feature', value_name='Value')

selected_features = melted['Feature'].unique()[:2]

subset = melted[melted['Feature'].isin(selected_features)]

subset1 = melted[melted['Feature'].isin(melted['Feature'].unique()[:2])]
subset2 = melted[melted['Feature'].isin(melted['Feature'].unique()[2:3])]
subset3 = melted[melted['Feature'].isin(melted['Feature'].unique()[3:17])]
subset4 = melted[melted['Feature'].isin(melted['Feature'].unique()[17:18])]
subset5 = melted[melted['Feature'].isin(melted['Feature'].unique()[18:20])]
subset6 = melted[melted['Feature'].isin(melted['Feature'].unique()[20:21])]
subset7 = melted[melted['Feature'].isin(melted['Feature'].unique()[21:])]

# %%
def subset_boxplot(data_melted, width, height):
    plt.figure(figsize = (width ,height))
    sns.boxplot(data=data_melted, x='Value', y='Feature')
    plt.yticks(fontsize=10)

# %%
# varying plot window for clear resolution of graph
subset_boxplot(subset1, width = 15, height = 5)
subset_boxplot(subset2, width = 15, height = 3)
subset_boxplot(subset3, width = 15, height = 8)
subset_boxplot(subset4, width = 15, height = 2)
subset_boxplot(subset5, width = 15, height = 4)
subset_boxplot(subset6, width = 15, height = 4)
subset_boxplot(subset7, width = 15, height = 6)

# %% [markdown]
# not all outliers will be removed from data as records represent real world students taken across different nationalities

# %%
outliers_cols = [
                 'Previous qualification (grade)', 
                 'Age at enrollment', 
                 'Curricular units 1st sem (credited)',
                 'Curricular units 1st sem (enrolled)', 
                 'Curricular units 1st sem (evaluations)', 
                 'Curricular units 2nd sem (credited)',
                 'Curricular units 2nd sem (enrolled)', 
                 'Curricular units 2nd sem (evaluations)'
                ]
print(outliers_cols)
# Out:
# ['Previous qualification (grade)', 'Age at enrollment', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)']

# %%
def iqr_detect(data, column_name):
    q3 = data[column_name].quantile(0.75)
    q1 = data[column_name].quantile(0.25)
    iqr = q3 - q1
    lower_limit = q1 - (1.5 * iqr)
    upper_limit = q3 + (1.5 * iqr)
    return lower_limit, upper_limit

# %%
def outliers_detect(data, columns):
    for col in columns:
        low_limit, up_limit = iqr_detect(data, col)
        if data[(data[col] > up_limit) | (data[col] < low_limit)].any(axis=None):
            number_of_outliers = data[(data[col] > up_limit) | (data[col] < low_limit)].shape[0]
            print(f"{col} ({low_limit}, {up_limit}): ", number_of_outliers, "outliers")

# %%
outliers_detect(numerical_data, outliers_cols)
# Out:
# Previous qualification (grade) (102.5, 162.5):  146 outliers
# Age at enrollment (10.0, 34.0):  389 outliers
# Curricular units 1st sem (credited) (0.0, 0.0):  480 outliers
# Curricular units 1st sem (enrolled) (2.0, 10.0):  366 outliers
# Curricular units 1st sem (evaluations) (0.0, 16.0):  136 outliers
# Curricular units 2nd sem (credited) (0.0, 0.0):  447 outliers
# Curricular units 2nd sem (enrolled) (2.0, 10.0):  321 outliers
# Curricular units 2nd sem (evaluations) (0.0, 16.0):  81 outliers

# %%
def get_outlier_students(data,  columns):
    outlier_mask = pd.Series(False, index=data.index)

    for col in columns:
        low, high = iqr_detect(data, col)
        if col in columns:
            mask = (data[col] < low) | (data[col] > high)
            outlier_mask |= mask  # Combine masks: True if any condition is True
    
    return data[outlier_mask]

# %%
print(f"total number of outliers to be removed: {get_outlier_students(numerical_data, outliers_cols).shape[0]}")
# Out:
# total number of outliers to be removed: 1041

# %%
outlier_students = get_outlier_students(numerical_data, outliers_cols)

clean_numerical_data = numerical_data.drop(index = outlier_students.index)
clean_ordinal_data = ordinal_df.drop(index = outlier_students.index)
clean_nominal_data = nominal_df.drop(index = outlier_students.index)
clean_target_data = target_data.drop(index = outlier_students.index)

print(f"Original shape: {numerical_data.shape}")
print(f"Cleaned numerical data shape: {clean_numerical_data.shape}")
print(f"Cleaned nominal data shape: {clean_nominal_data.shape}")
print(f"Cleaned ordinal data shape: {clean_ordinal_data.shape}")
print(f"cleaned target shape: {clean_target_data.shape}")
# Out:
# Original shape: (3630, 28)
# Cleaned numerical data shape: (2589, 28)
# Cleaned nominal data shape: (2589, 207)
# Cleaned ordinal data shape: (2589, 1)
# cleaned target shape: (2589,)

# %% [markdown]
# # removing unused dummies of nominal categories

# %%
print(f"all uniques values in data: {clean_nominal_data.nunique().sum()}")
clean_nominal_data.nunique()
# Out:
# all uniques values in data: 388
# Marital status_divorced             2
# Marital status_facto union          2
# Marital status_legally separated    2
# Marital status_married              2
# Marital status_single               2
#                                    ..
# Tuition fees up to date_yes         2
# Gender_female                       2
# Gender_male                         2
# Scholarship holder_no               2
# Scholarship holder_yes              2
# Length: 207, dtype: int64

# %% [markdown]
# All dummies of nominal categorical features having a single unique value will be removed (which is 'No'), i.e. category hasn't been chosen for any student

# %%
print(f"total features before removal: {clean_nominal_data.shape[1]}")
# Out:
# total features before removal: 207

# %%
dummies = nominal_df.columns

for i in dummies:
    if clean_nominal_data[i].nunique() == 1:
         clean_nominal_data.drop(i, axis=1, inplace=True)
         print(f"{i} was removed")
# Out:
# Course_Animation and Multimedia Design was removed
# Previous qualification_10th year of schooling was removed
# Previous qualification_10th year of schooling - not completed was removed
# Previous qualification_doctorate was removed
# Nacionality_English was removed
# Nacionality_Mozambican was removed
# Mother's qualification_2nd cycle general HS was removed
# Mother's qualification_Can't read/write was removed
# Mother's qualification_Doctorate (3rd cycle) was removed
# Father's qualification_Admin & Commerce was removed
# Father's qualification_Can't read/write was removed
# Father's qualification_Complementary HS Not Concluded was removed
# Father's qualification_Doctorate (3rd cycle) was removed
# Father's qualification_Specialized higher was removed
# Mother's occupation_Armed Forces was removed
# Mother's occupation_Finance/statistics/registry ops was removed
# Mother's occupation_ICT specialists was removed
# Mother's occupation_Legal/social/sports techs was removed
# Father's occupation_Admin service managers was removed
# Father's occupation_Army Officers was removed
# Father's occupation_Army Sergeants was removed
# Father's occupation_Finance/PR/Org specialists was removed
# Father's occupation_Finance/statistics/registry ops was removed
# Father's occupation_ICT techs was removed
# Father's occupation_Metal workers was removed
# Father's occupation_Secretaries & data ops was removed

# %%
print(f"total features after removal: {clean_nominal_data.shape[1]}")
# Out:
# total features after removal: 181

# %% [markdown]
# # Encoding target

# %%
clean_target_data.head()
# Out:
# 1    Graduate
# 2     Dropout
# 3    Graduate
# 6    Graduate
# 7     Dropout
# Name: Target, dtype: object

# %%
mapping = {"Dropout": 0, "Graduate": 1}
clean_target_data = clean_target_data.map(mapping)

# %%
clean_target_data.head()
# Out:
# 1    1
# 2    0
# 3    1
# 6    1
# 7    0
# Name: Target, dtype: int64

# %% [markdown]
# # Splitting data into train and test

# %%
from sklearn.model_selection import train_test_split

clean_features = pd.concat([clean_numerical_data, clean_ordinal_data, clean_nominal_data], axis=1)

X_train, X_test, y_train, y_test = train_test_split(clean_features, clean_target_data, test_size=0.2, random_state=42)

print(f"X_Train shape: {X_train.shape}")
print(f"X_Test shape: {X_test.shape}")
print(f"y_Train shape: {y_train.shape}")
print(f"y_Test shape: {y_test.shape}")
# Out:
# X_Train shape: (2071, 210)
# X_Test shape: (518, 210)
# y_Train shape: (2071,)
# y_Test shape: (518,)

# %% [markdown]
# # Scaling data

# %%
X_train_to_scale = pd.concat([X_train[clean_numerical_data.columns], X_train[clean_ordinal_data.columns]], axis=1)

X_test_to_scale = pd.concat([X_test[clean_numerical_data.columns], X_test[clean_ordinal_data.columns]], axis=1)

# %%
X_train_to_scale.describe()
# Out:
#        Previous qualification (grade)  Admission grade  Age at enrollment  \
# count                     2071.000000      2071.000000        2071.000000
# mean                       132.631869       125.955336          20.742154
# std                         11.036082        12.361357           3.800986
# min                        103.000000        95.000000          17.000000
# 25%                        125.000000       118.000000          18.000000
# 50%                        133.100000       125.600000          19.000000
# 75%                        140.000000       132.800000          21.000000
# max                        162.000000       172.000000          34.000000
#
#        Curricular units 1st sem (credited)  \
# count                               2071.0
# mean                                   0.0
# std                                    0.0
# min                                    0.0
# 25%                                    0.0
# 50%                                    0.0
# 75%                                    0.0
# max                                    0.0
#
#        Curricular units 1st sem (enrolled)  \
# count                          2071.000000
# mean                              6.093192
# std                               0.918677
# min                               2.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                               8.000000
#
#        Curricular units 1st sem (evaluations)  \
# count                             2071.000000
# mean                                 7.653308
# std                                  2.798298
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                  9.000000
# max                                 16.000000
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# count                          2071.000000                       2071.000000
# mean                              4.601642                         11.046800
# std                               2.339160                          4.583248
# min                               0.000000                          0.000000
# 25%                               3.500000                         11.333333
# 50%                               5.000000                         12.537500
# 75%                               6.000000                         13.530952
# max                               8.000000                         18.000000
#
#        Curricular units 1st sem (without evaluations)  \
# count                                     2071.000000
# mean                                         0.101883
# std                                          0.556691
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          8.000000
#
#        Curricular units 2nd sem (credited)  ...  grade_per_credit_sem_1  \
# count                               2071.0  ...             2071.000000
# mean                                   0.0  ...                2.425803
# std                                    0.0  ...                1.927095
# min                                    0.0  ...                0.000000
# 25%                                    0.0  ...                1.910099
# 50%                                    0.0  ...                2.222219
# 75%                                    0.0  ...                2.641424
# max                                    0.0  ...               17.999820
#
#        grade_per_credit_sem_2   grade_diff     improved  \
# count             2071.000000  2071.000000  2071.000000
# mean                 2.257629    -0.517776     0.345727
# std                  1.939769     2.913214     0.475719
# min                  0.000000   -16.000000     0.000000
# 25%                  1.749650    -0.600000     0.000000
# 50%                  2.145830     0.000000     0.000000
# 75%                  2.599995     0.440446     1.000000
# max                 15.999840    14.500000     1.000000
#
#        cumulative_approval_rate  grade_points_avg  age_penalty  \
# count               2071.000000       2071.000000  2071.000000
# mean                   0.594758         10.838050     0.047108
# std                    0.339780          4.617855     0.006460
# min                    0.000000          0.000000     0.028571
# 25%                    0.333333         11.212721     0.045455
# 50%                    0.687500         12.485706     0.050000
# 75%                    0.874999         13.471396     0.052632
# max                    0.999999         17.153833     0.055556
#
#        approved_rate_sem_1  approved_rate_sem_2  Application order
# count          2071.000000          2071.000000        2071.000000
# mean              0.611466             0.589476           1.961854
# std               0.345141             0.365462           1.463895
# min               0.000000             0.000000           1.000000
# 25%               0.363636             0.279220           1.000000
# 50%               0.714285             0.699999           1.000000
# 75%               0.874999             0.874999           3.000000
# max               0.999999             0.999999           6.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# normalizing distribution of data using Standard Scaler library in python

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_to_scale)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train_to_scale.columns, index=X_train.index)

X_test_scaled = scaler.transform(X_test_to_scale)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test_to_scale.columns, index=X_test.index)

# %%
X_train_to_scale.describe()
# Out:
#        Previous qualification (grade)  Admission grade  Age at enrollment  \
# count                     2071.000000      2071.000000        2071.000000
# mean                       132.631869       125.955336          20.742154
# std                         11.036082        12.361357           3.800986
# min                        103.000000        95.000000          17.000000
# 25%                        125.000000       118.000000          18.000000
# 50%                        133.100000       125.600000          19.000000
# 75%                        140.000000       132.800000          21.000000
# max                        162.000000       172.000000          34.000000
#
#        Curricular units 1st sem (credited)  \
# count                               2071.0
# mean                                   0.0
# std                                    0.0
# min                                    0.0
# 25%                                    0.0
# 50%                                    0.0
# 75%                                    0.0
# max                                    0.0
#
#        Curricular units 1st sem (enrolled)  \
# count                          2071.000000
# mean                              6.093192
# std                               0.918677
# min                               2.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                               8.000000
#
#        Curricular units 1st sem (evaluations)  \
# count                             2071.000000
# mean                                 7.653308
# std                                  2.798298
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                  9.000000
# max                                 16.000000
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# count                          2071.000000                       2071.000000
# mean                              4.601642                         11.046800
# std                               2.339160                          4.583248
# min                               0.000000                          0.000000
# 25%                               3.500000                         11.333333
# 50%                               5.000000                         12.537500
# 75%                               6.000000                         13.530952
# max                               8.000000                         18.000000
#
#        Curricular units 1st sem (without evaluations)  \
# count                                     2071.000000
# mean                                         0.101883
# std                                          0.556691
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          8.000000
#
#        Curricular units 2nd sem (credited)  ...  grade_per_credit_sem_1  \
# count                               2071.0  ...             2071.000000
# mean                                   0.0  ...                2.425803
# std                                    0.0  ...                1.927095
# min                                    0.0  ...                0.000000
# 25%                                    0.0  ...                1.910099
# 50%                                    0.0  ...                2.222219
# 75%                                    0.0  ...                2.641424
# max                                    0.0  ...               17.999820
#
#        grade_per_credit_sem_2   grade_diff     improved  \
# count             2071.000000  2071.000000  2071.000000
# mean                 2.257629    -0.517776     0.345727
# std                  1.939769     2.913214     0.475719
# min                  0.000000   -16.000000     0.000000
# 25%                  1.749650    -0.600000     0.000000
# 50%                  2.145830     0.000000     0.000000
# 75%                  2.599995     0.440446     1.000000
# max                 15.999840    14.500000     1.000000
#
#        cumulative_approval_rate  grade_points_avg  age_penalty  \
# count               2071.000000       2071.000000  2071.000000
# mean                   0.594758         10.838050     0.047108
# std                    0.339780          4.617855     0.006460
# min                    0.000000          0.000000     0.028571
# 25%                    0.333333         11.212721     0.045455
# 50%                    0.687500         12.485706     0.050000
# 75%                    0.874999         13.471396     0.052632
# max                    0.999999         17.153833     0.055556
#
#        approved_rate_sem_1  approved_rate_sem_2  Application order
# count          2071.000000          2071.000000        2071.000000
# mean              0.611466             0.589476           1.961854
# std               0.345141             0.365462           1.463895
# min               0.000000             0.000000           1.000000
# 25%               0.363636             0.279220           1.000000
# 50%               0.714285             0.699999           1.000000
# 75%               0.874999             0.874999           3.000000
# max               0.999999             0.999999           6.000000
#
# [8 rows x 29 columns]

# %%
X_train_nominal = X_train[clean_nominal_data.columns]
X_test_nominal = X_test[clean_nominal_data.columns]

X_train_final = pd.concat([X_train_scaled_df, X_train_nominal], axis=1)
X_test_final = pd.concat([X_test_scaled_df, X_test_nominal], axis=1)

# %%
X_train_final.head()
# Out:
#       Previous qualification (grade)  Admission grade  Age at enrollment  \
# 1932                       -0.691705        -0.643720          -0.721606
# 2585                       -1.144874        -0.676087          -0.458453
# 1459                       -1.235507        -1.129221          -0.195300
# 43                         -1.144874        -0.368603          -0.195300
# 1233                        0.042428        -0.886471          -0.458453
#
#       Curricular units 1st sem (credited)  \
# 1932                                  0.0
# 2585                                  0.0
# 1459                                  0.0
# 43                                    0.0
# 1233                                  0.0
#
#       Curricular units 1st sem (enrolled)  \
# 1932                            -0.101466
# 2585                            -0.101466
# 1459                            -1.190250
# 43                              -0.101466
# 1233                            -0.101466
#
#       Curricular units 1st sem (evaluations)  \
# 1932                                0.481370
# 2585                                0.123924
# 1459                               -0.948415
# 43                                 -0.233522
# 1233                               -0.590969
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 1932                             0.170341                         -0.010213
# 2585                             0.170341                          0.251673
# 1459                            -1.967695                         -2.410838
# 43                              -0.257266                          0.426264
# 1233                             0.597948                          0.389891
#
#       Curricular units 1st sem (without evaluations)  \
# 1932                                        -0.18306
# 2585                                        -0.18306
# 1459                                        -0.18306
# 43                                          -0.18306
# 1233                                        -0.18306
#
#       Curricular units 2nd sem (credited)  ...  Educational special needs_no  \
# 1932                                  0.0  ...                           1.0
# 2585                                  0.0  ...                           1.0
# 1459                                  0.0  ...                           1.0
# 43                                    0.0  ...                           1.0
# 1233                                  0.0  ...                           1.0
#
#       Educational special needs_yes  Debtor_no  Debtor_yes  \
# 1932                            0.0        1.0         0.0
# 2585                            0.0        1.0         0.0
# 1459                            0.0        1.0         0.0
# 43                              0.0        1.0         0.0
# 1233                            0.0        1.0         0.0
#
#       Tuition fees up to date_no  Tuition fees up to date_yes  Gender_female  \
# 1932                         0.0                          1.0            1.0
# 2585                         0.0                          1.0            1.0
# 1459                         1.0                          0.0            0.0
# 43                           1.0                          0.0            1.0
# 1233                         0.0                          1.0            1.0
#
#       Gender_male  Scholarship holder_no  Scholarship holder_yes
# 1932          0.0                    1.0                     0.0
# 2585          0.0                    1.0                     0.0
# 1459          1.0                    1.0                     0.0
# 43            0.0                    1.0                     0.0
# 1233          0.0                    1.0                     0.0
#
# [5 rows x 210 columns]

# %%
#correlation 
corr_train = pd.concat([clean_target_data, X_train_scaled_df], axis = 1).corr()
plt.figure(figsize  = (20, 8))
sns.heatmap(corr_train, annot = True, cmap = "Blues", linewidth = 0.1)
# Out:
# <Axes: >

# %%
plt.figure(figsize= (18, 10))
sns.heatmap(corr_train[(corr_train >= 0.45) | (corr_train <= -0.45)], annot = True, linewidth = 0.1, cmap = 'Blues')
# Out:
# <Axes: >

# %%
corr_train['Target']
# Out:
# Target                                            1.000000
# Previous qualification (grade)                    0.129501
# Admission grade                                   0.131043
# Age at enrollment                                -0.332569
# Curricular units 1st sem (credited)                    NaN
# Curricular units 1st sem (enrolled)               0.291858
# Curricular units 1st sem (evaluations)            0.030106
# Curricular units 1st sem (approved)               0.727606
# Curricular units 1st sem (grade)                  0.588689
# Curricular units 1st sem (without evaluations)   -0.130334
# Curricular units 2nd sem (credited)                    NaN
# Curricular units 2nd sem (enrolled)               0.291331
# Curricular units 2nd sem (evaluations)            0.134098
# Curricular units 2nd sem (approved)               0.774744
# Curricular units 2nd sem (grade)                  0.671316
# Curricular units 2nd sem (without evaluations)   -0.131199
# Unemployment rate                                 0.039415
# Inflation rate                                   -0.032948
# GDP                                               0.049557
# grade_increase_ratio                              0.636617
# grade_per_credit_sem_1                           -0.089828
# grade_per_credit_sem_2                            0.008064
# grade_diff                                        0.256283
# improved                                          0.197936
# cumulative_approval_rate                          0.762822
# grade_points_avg                                  0.650599
# age_penalty                                       0.344701
# approved_rate_sem_1                               0.709299
# approved_rate_sem_2                               0.765549
# Application order                                 0.061583
# Name: Target, dtype: float64

# %% [markdown]
# extracted features appear to have high correlation with target

# %% [markdown]
# # Model Implementation

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score

def performance(y_tests, y_pred, y_proba):

    #model evaluation 
    print(f"Model's accuracy: {accuracy_score(y_tests, y_pred)}")
    
    cm = confusion_matrix(y_pred, y_tests)
    plt.figure(figsize = (5, 5))
    sns.heatmap(cm, annot = True, fmt = 'd', cmap = 'Blues', yticklabels=['Drop Out', 'Graduate'], xticklabels=['Drop Out', 'Graduate'])
    plt.ylabel('predictions')
    plt.xlabel('Real values')
    plt.title('confusion matrix')
    plt.show()
    
    print(classification_report(y_tests, y_pred))
    
    fpr, tpr, _ = roc_curve(y_tests, y_proba)
    auc_rf = roc_auc_score(y_tests, y_proba)
    
    # Plot
    plt.figure(figsize=(5, 5))
    plt.plot(fpr, tpr, label=f"Model (AUC = {auc_rf:.3f})", color='blue')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend(loc="upper left")  
    plt.show()

# %% [markdown]
# we will train the model on the whole old data before any preprocessing to evaluate the progress of the project

# %%
features = pd.concat([
               numerical_data.drop(added_features, axis = 1), ordinal_df, nominal_df], axis=1)



X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(features, target_data.map({"Dropout": 0, "Graduate": 1}), test_size=0.2, random_state=42)

print(features.shape)
print(target_data.shape)
print(f"X_Train shape: {X_train_raw.shape}")
print(f"X_Test shape: {X_test_raw.shape}")
print(f"y_Train shape: {y_train_raw.shape}")
print(f"y_Test shape: {y_test_raw.shape}")
# Out:
# (3630, 226)
# (3630,)
# X_Train shape: (2904, 226)
# X_Test shape: (726, 226)
# y_Train shape: (2904,)
# y_Test shape: (726,)

# %%
from sklearn.linear_model import LogisticRegression

lr_raw = LogisticRegression()
lr_raw.fit(X_train_raw, y_train_raw)
lr_raw_pred = lr_raw.predict(X_test_raw)
lr_raw_proba = lr_raw.predict_proba(X_test_raw)[:, 1]
performance(y_test_raw, lr_raw_pred, lr_raw_proba)
# Out:
# Model's accuracy: 0.9090909090909091
# C:\Users\youss\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       277
#            1       0.90      0.95      0.93       449
#
#     accuracy                           0.91       726
#    macro avg       0.91      0.90      0.90       726
# weighted avg       0.91      0.91      0.91       726

# %%
print(clean_features.shape)
print(clean_target_data.shape)

print(f"X_Train shape: {X_train_final.shape}")
print(f"X_Test shape: {X_test_final.shape}")
print(f"y_Train shape: {y_train.shape}")
print(f"y_Test shape: {y_test.shape}")
# Out:
# (2589, 210)
# (2589,)
# X_Train shape: (2071, 210)
# X_Test shape: (518, 210)
# y_Train shape: (2071,)
# y_Test shape: (518,)

# %%
from sklearn.linear_model import LogisticRegression

lr_clean = LogisticRegression()
lr_clean.fit(X_train_final, y_train)
lr_clean_pred = lr_clean.predict(X_test_final)
lr_clean_proba = lr_clean.predict_proba(X_test_final)[:, 1]
performance(y_test, lr_clean_pred, lr_clean_proba)
# Out:
# Model's accuracy: 0.9420849420849421
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       170
#            1       0.94      0.97      0.96       348
#
#     accuracy                           0.94       518
#    macro avg       0.94      0.93      0.93       518
# weighted avg       0.94      0.94      0.94       518

# %%
from sklearn.metrics import log_loss

print(f"the loss of the raw model: {log_loss(y_test_raw, lr_raw_proba)}")
print(f"the loss of the clean model: {log_loss(y_test, lr_clean_proba)}")
# Out:
# the loss of the raw model: 0.2366281979520154
# the loss of the clean model: 0.18123245548247785

# %%
from sklearn.linear_model import LogisticRegression

lr_clean = LogisticRegression(solver='newton-cg')
lr_clean.fit(X_train_final, y_train)
lr_clean_pred = lr_clean.predict(X_test_final)
lr_clean_proba = lr_clean.predict_proba(X_test_final)[:, 1]
performance(y_test, lr_clean_pred, lr_clean_proba)
print(log_loss(y_test, lr_clean_proba))
# Out:
# Model's accuracy: 0.9420849420849421
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       170
#            1       0.94      0.97      0.96       348
#
#     accuracy                           0.94       518
#    macro avg       0.94      0.93      0.93       518
# weighted avg       0.94      0.94      0.94       518
# 0.1811413048065963

# %% [markdown]
# # perceprton implementation

# %%
from sklearn.neural_network import MLPClassifier


mlp = MLPClassifier(
    hidden_layer_sizes=(80,30),   # One hidden layer with 100 neurons
    activation='relu',           # Activation function: 'relu', 'tanh', 'logistic'
    solver='adam',               # Optimizer: 'adam', 'sgd', 'lbfgs'
    learning_rate='adaptive',    # or 'constant', 'invscaling'
    max_iter=300,                # Max training iterations
    # early_stopping=True,         # Stop early if no improvement
    verbose=True,
    random_state=42
)

# %%
mlp.fit(X_train_final, y_train)
# Out:
# Iteration 1, loss = 0.50207290
# Iteration 2, loss = 0.32886533
# Iteration 3, loss = 0.27553402
# Iteration 4, loss = 0.25093123
# Iteration 5, loss = 0.23345473
# Iteration 6, loss = 0.21973325
# Iteration 7, loss = 0.20889201
# Iteration 8, loss = 0.20042489
# Iteration 9, loss = 0.19083730
# Iteration 10, loss = 0.18486718
# Iteration 11, loss = 0.17817210
# Iteration 12, loss = 0.17281459
# Iteration 13, loss = 0.16640039
# Iteration 14, loss = 0.16135913
# Iteration 15, loss = 0.15732058
# Iteration 16, loss = 0.15249688
# Iteration 17, loss = 0.14770871
# Iteration 18, loss = 0.14291392
# Iteration 19, loss = 0.13718674
# Iteration 20, loss = 0.13209636
# Iteration 21, loss = 0.12766891
# Iteration 22, loss = 0.12175856
# Iteration 23, loss = 0.11781391
# Iteration 24, loss = 0.11274392
# Iteration 25, loss = 0.10896624
# Iteration 26, loss = 0.10470862
# Iteration 27, loss = 0.09945276
# Iteration 28, loss = 0.09568223
# Iteration 29, loss = 0.09066966
# Iteration 30, loss = 0.08695774
# Iteration 31, loss = 0.08324077
# Iteration 32, loss = 0.07945828
# Iteration 33, loss = 0.07759348
# Iteration 34, loss = 0.07181559
# Iteration 35, loss = 0.06735496
# Iteration 36, loss = 0.06312895
# Iteration 37, loss = 0.06013429
# Iteration 38, loss = 0.05892254
# Iteration 39, loss = 0.05421944
# Iteration 40, loss = 0.05066727
# Iteration 41, loss = 0.04751987
# Iteration 42, loss = 0.04501188
# Iteration 43, loss = 0.04271043
# Iteration 44, loss = 0.03946213
# Iteration 45, loss = 0.03650147
# Iteration 46, loss = 0.03422541
# Iteration 47, loss = 0.03246660
# Iteration 48, loss = 0.02965572
# Iteration 49, loss = 0.02727667
# Iteration 50, loss = 0.02498291
# Iteration 51, loss = 0.02570436
# Iteration 52, loss = 0.02313667
# Iteration 53, loss = 0.02328093
# Iteration 54, loss = 0.02015646
# Iteration 55, loss = 0.01864361
# Iteration 56, loss = 0.01677466
# Iteration 57, loss = 0.01571155
# Iteration 58, loss = 0.01543045
# Iteration 59, loss = 0.01423499
# Iteration 60, loss = 0.01299936
# Iteration 61, loss = 0.01216484
# Iteration 62, loss = 0.01155753
# Iteration 63, loss = 0.01077372
# Iteration 64, loss = 0.01029007
# Iteration 65, loss = 0.01026743
# Iteration 66, loss = 0.00944152
# Iteration 67, loss = 0.00914955
# Iteration 68, loss = 0.00848798
# Iteration 69, loss = 0.00788467
# Iteration 70, loss = 0.00726738
# Iteration 71, loss = 0.00760302
# Iteration 72, loss = 0.00683871
# Iteration 73, loss = 0.00600545
# Iteration 74, loss = 0.00567026
# Iteration 75, loss = 0.00545838
# Iteration 76, loss = 0.00514768
# Iteration 77, loss = 0.00486757
# Iteration 78, loss = 0.00463788
# Iteration 79, loss = 0.00443633
# Iteration 80, loss = 0.00425043
# Iteration 81, loss = 0.00406241
# Iteration 82, loss = 0.00386110
# Iteration 83, loss = 0.00370513
# Iteration 84, loss = 0.00358023
# Iteration 85, loss = 0.00346815
# Iteration 86, loss = 0.00334008
# Iteration 87, loss = 0.00315083
# Iteration 88, loss = 0.00306813
# Iteration 89, loss = 0.00300161
# Iteration 90, loss = 0.00279078
# Iteration 91, loss = 0.00267964
# Iteration 92, loss = 0.00257023
# Iteration 93, loss = 0.00252472
# Iteration 94, loss = 0.00245624
# Iteration 95, loss = 0.00241108
# Iteration 96, loss = 0.00228571
# Iteration 97, loss = 0.00221587
# Iteration 98, loss = 0.00210111
# Iteration 99, loss = 0.00201301
# Iteration 100, loss = 0.00193655
# Iteration 101, loss = 0.00188635
# Iteration 102, loss = 0.00182328
# Iteration 103, loss = 0.00176152
# Iteration 104, loss = 0.00173479
# Iteration 105, loss = 0.00167479
# Iteration 106, loss = 0.00163063
# Iteration 107, loss = 0.00156734
# Iteration 108, loss = 0.00153201
# Iteration 109, loss = 0.00151123
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(80, 30), learning_rate='adaptive',
#               max_iter=300, random_state=42, verbose=True)

# %%
plt.plot(mlp.loss_curve_)
plt.title("Training Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
y_pred = mlp.predict(X_test_final)
y_proba = mlp.predict_proba(X_test_final)[:, 1]
print("\n✅ Evaluation:")
performance(y_test, y_pred, y_proba)
# Out:
# ✅ Evaluation:
# Model's accuracy: 0.9420849420849421
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       170
#            1       0.94      0.97      0.96       348
#
#     accuracy                           0.94       518
#    macro avg       0.94      0.93      0.93       518
# weighted avg       0.94      0.94      0.94       518

# %%
print("\n🧠 Model Internals:")
print(f"Epochs completed: {mlp.n_iter_}")
print(f"Best validation loss: {mlp.best_loss_:.4f}")
print(f"Number of layers (including input/output): {len(mlp.coefs_) + 1}")
print(f"Shape of input-to-hidden weights: {mlp.coefs_[0].shape}")
print(f"Shape of hidden-to-output weights: {mlp.coefs_[-1].shape}")
# Out:
# 🧠 Model Internals:
# Epochs completed: 109
# Best validation loss: 0.0015
# Number of layers (including input/output): 4
# Shape of input-to-hidden weights: (210, 80)
# Shape of hidden-to-output weights: (30, 1)

# %% [markdown]
# # saving model for usage and deployment

# %%
import joblib

# Save model and scalers
joblib.dump(mlp, 'mlp_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(onehot_encoder, 'nominal_encoder.pkl')  # e.g., OneHotEncoder
joblib.dump(ordinal_encoder, 'ordinal_encoder.pkl')  # if applicable
